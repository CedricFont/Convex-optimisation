# %% [markdown]
# # Project 3 : image denoising and reconstruction
# ## Part I : Image denoising

# %%
import numpy as np
from matplotlib import image
from matplotlib import pyplot
from numpy import random as rnd
import cvxpy as cp

# %%
dog = image.imread('dog.png')
pyplot.imshow(dog)
pyplot.show()

dog_noisy = dog + 20*rnd.normal(size=(dog.shape[0],dog.shape[1]))
dog_noisy[dog_noisy>255] = 255
dog_noisy[dog_noisy<0] = 0

pyplot.imshow(dog_noisy)
pyplot.show()

# %%
n = 256
rho =
X = cp.Variable((n,n))
Y = cp.Variable((n-1,n))
Z = cp.Variable((n,n-1))
t = cp.Variable(1)

objective = cp.Minimize(t + rho*(cp.sum(Y) + cp.sum(Z)))

constraints = []

constraints.append(cp.norm(cp.vec(X) - cp.vec(dog_noisy),2) <= t)
constraints.append(-Y <= X[1:,:] - dog_noisy[:n-1,:] <= Y)
constraints.append(-Z <= X[:,1:] - dog_noisy[:,:n-1] <= Z)
